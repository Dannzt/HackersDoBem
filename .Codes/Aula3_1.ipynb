# %% [markdown]
# #Estrutura Condicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Exemplo 1
idade = int(input("Digite sua idade: "))
if (idade >= 18):
  print(f"Com {idade} anos você já é maior de idade")
  if (idade >= 60):
    print("e já pode se aposentar")
else:
   print(f"Com {idade} anos você ainda é menor de idade")
print("FIM DO PROGRAMA :)")

## a estrutura do if do python é diferente do C, onde a estrutura do if tem que ser embaixo do campo dele, a identação (com o espaço do tab na frente da linha desejada) e usa :
## e não precisa das chaves, que é mais pratico e agradavel mas é meio estranho kkkkkk
# Out:
# Digite sua idade: 70
# Com 70 anos você já é maior de idade
# Você já pode se aposentar
# FIM DO PROGRAMA :)

# %%
#Exemplo 2
idade = int(input("Digite sua idade: "))
if (idade >= 18):
  print(f"Com {idade} anos você já é maior de idade")
else:
   print(f"Com {idade} anos você ainda é menor de idade")
print("FIM DO PROGRAMA :)")
# Out:
# Digite sua idade: 17
# Com 17 anos você ainda é menor de idade
# FIM DO PROGRAMA :)

# %%
#Exemplo 3
print("Responda apenas com sim ou não (com acento)")
resposta = input("O seu time ganhou a Copa do Brasil de 2024 contra o Galo esse final de semana? (10/11/2024)\n")
if((resposta == "sim")or(resposta == "Sim")or(resposta == "SIM")):
  print("GRAÇAS A DEUS! \n")
  print("UMA FEZ FLAMENGO SEMPRE FLAMENGO,O FLAMENGO É O MEU EU DE SER É O MEU MAIOR PRAZER VE-LÔ HUMILHAR, SEJÁ NA TERRA, SEJÁ NO MAR,VENCEU VENCEU VENCEU!")
  print("Teve galo frito pro jantarkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk")
if((resposta == "não")or(resposta == "Não")or(resposta == "NÃO")):
  print("Que pena mano :( \n")
  print("Venha pelo lado rubro negro da força, o Flamengo te espera.")

print("\n\nFIM DO PROGRAMA :)")
# Out:
# Responda apenas com sim ou não (com acento)
# O seu time ganhou a Copa do Brasil de 2024 contra o Galo esse final de semana? (10/11/2024)
# sim
# GRAÇAS A DEUS!
#
# UMA FEZ FLAMENGO SEMPRE FLAMENGO,O FLAMENGO É O MEU EU DE SER É O MEU MAIOR PRAZER VE-LÔ HUMILHAR, SEJÁ NA TERRA, SEJÁ NO MAR,VENCEU VENCEU VENCEU!
# Teve galo frito pro jantarkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
#
#
# FIM DO PROGRAMA :)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Exemplo 4
print("Digite a nota do aluno: ")
media = int(input("Digite a nota final do aluno: (0 a 100)"))

if(media>=50):
  print(f"com a nota {media} o aluno está aprovado")
else:
  print(f"com a nota {media} o aluno está reprovado")

print("\n\nFIM DO PROGRAMA :)")
# Out:
# Digite a nota do aluno:
# Digite a nota final do aluno: (0 a 100)76
# com a nota 76 o aluno está aprovado
#
#
# FIM DO PROGRAMA :)

# %%
#Exemplo 5
print('='*114)
print("Digite somente com sim ou não (com acento)")
print('='*114)
resposta = input("O seu time ganhou a Copa do Brasil de 2024 contra o Galo esse final de semana? (10/11/2024)")
if((resposta == "sim")or(resposta == "Sim")or(resposta == "SIM")):
  print("NÃO TEM JEITO, É O MENGUDO")
  print("UMA FEZ FLAMENGO SEMPRE FLAMENGO,O FLAMENGO É O MEU EU DE SER É O MEU MAIOR PRAZER VE-LÔ HUMILHAR, SEJÁ NA TERRA, SEJÁ NO MAR,VENCEU VENCEU VENCE")
  print("Teve galo frito pro jantarkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk")
if((resposta == "não")or(resposta == "Não")or(resposta == "NÃO")):
  print("Que pena mano :( \n")
  print("Venha pelo lado rubro negro da força, o Flamengo te espera.")
else:
  print("Resposta Invalida, responda somente com sim ou não")

print('='*114)
print("\n\nFIM DO PROGRAMA:)")
# Out:
# ...
# Digite somente com sim ou não (com acento)
# ...
# O seu time ganhou a Copa do Brasil de 2024 contra o Galo esse final de semana? (10/11/2024)sim
# NÃO TEM JEITO, É O MENGUDO
# UMA FEZ FLAMENGO SEMPRE FLAMENGO,O FLAMENGO É O MEU EU DE SER É O MEU MAIOR PRAZER VE-LÔ HUMILHAR, SEJÁ NA TERRA, SEJÁ NO MAR,VENCEU VENCEU VENCE
# Teve galo frito pro jantarkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Resposta Invalida, responda somente com sim ou não
# ...
#
#
# FIM DO PROGRAMA:)

# %% [markdown]
# # Estruturas Condicionais Encadeadas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exemplo:
# <br>Conversão de notas
#
# ![image.png](data:image/png;base64,...)

# %%
print("="*65)
print("Sempre informe a nota com o . (ponto final) caso tenha décimos")
print("="*65)

nota = float(input("Digite a nota do aluno: "))

if (nota>=9):
  print(f"Nota {nota} Conceito A")
elif((nota>=7)):
  print(f"Nota {nota} Conceito B")
elif((nota>=6)):
  print(f"Nota {nota} Conceito C")
elif((nota>=5)):
  print(f"Nota {nota} Conceito D")
elif((nota>=4)):
  print(f"Nota {nota} Conceito E")
else:
  print(f"Nota {nota} Conceito F")
  print("Infelizmente o aluno está reprovado")
# Out:
# ...
# Sempre informe a nota com o . (ponto final) caso tenha décimos
# ...
# Digite a nota do aluno: 8.6
# Nota 8.6 Conceito B
