# %% [markdown]
# #Operadores Relacionais

# %% [markdown]
# Operadores relacionais é usado para comparação entre valores, com o resultado sendo tipo logico (True or False) <br>
#
#
# Igualdade  == <br>
# Diferente  != <br>
# Maior       >   <br>
# Maior igual >= <br>
# Menor < <br>
# Menor igual <= <br>

# %%
10!=6
# Out:
# True

# %%
num = int(input("Digite um número qualquer: "))
comparacao = int(input("Digite outro numero para uma comparação: "))

resultado = 2*num+3
print(f"O resoltado da comparação é {resultado >= comparacao}")
# Out:
# Digite um número qualquer 20
# Digite outro numero para uma comparação 20
# O resoltado da comparação é True

# %% [markdown]
# #Operadores Logicos

# %% [markdown]
# Novamente são formas de comparação, entre tanto ele compara entre duas variaveis logicas, os operadores lógicos são: <br>
#
#  Operador | Instrução <br>
#  E        | and <br>
#  ou       | or <br>
#  Não      | not <br>
#
#
#
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Operdador and

# %%
entrada_1 = True
entrada_2 = True

print(f"{entrada_1} and {entrada_2} = {entrada_1 and entrada_2}")
# Out:
# True and True = True

# %%
((2*2+3) == 7) and ((2+2) != 3) and (5*2 == 10)
# analisa primeiro os parenteses, depois com todos os parenteses dando valores verdadeiros (true) os ands descem e com a somatoria de (true + true + true = true)
# Out:
# True

# %%
((2*2+3) == 7) and ((2+2) != 3) and (5*2 == 11)
# ele analisa primerios os parenteses, e como falei anteriormente verifica se todos os valores são true, mas 5*2 não é 11, então descendo um false o resultado fica (true + ture + false = false)
# Out:
# False

# %% [markdown]
# ## Operador or

# %%
entrada_1 = False
entrada_2 = True

print(f"{entrada_1} or {entrada_2} = {entrada_1 or entrada_2}")
# Out:
# False or True = True

# %%
entrada_1 = False
entrada_2 = False

print(f"{entrada_1} or {entrada_2} = {entrada_1 or entrada_2}")
# Out:
# False or False = False

# %%
entrada_1 = True
entrada_2 = False

print(f"{entrada_1} or {entrada_2} = {entrada_1 or entrada_2}")
# Out:
# True or False = True

# %%
((2*2+3) ==6) or ((2+2) != 4) or (5*2 != 10)
# analisa primeiro os parenteses, depois com todos os parenteses dando valores falso (False) os or descem e com a somatoria de (False + Falase + false = False)
# Out:
# False

# %%
((2*2+3) == 7) or ((2+2) != 3) or (5*2 == 10)
# analisa primeiro os parenteses, depois com todos os parenteses dando valores verdadeiros (true) os or descem e com a somatoria de (true + true + true = true)
# Out:
# True

# %%
entrada_1 = True
entrada_2 = False
entrada_3 = True

(entrada_1 and entrada_2) or entrada_3
# Out:
# True

# %% [markdown]
# ## Operador not

# %%
entrada = True

print(f"not {entrada} = {not entrada}")
# Out:
# not True = False

# %%
entrada = False

print(f"not {entrada} = {not entrada}")
# Out:
# not False = True

# %%
entrada_1 = True
entrada_2 = False
entrada_3 = True

(entrada_1 and entrada_2) or not entrada_3
# Out:
# False

# %%
entrada_1 = (2*2+3) == 7
entrada_2 = (2+2) != 3
entrada_3 = 5*2 == 10

(entrada_1 and entrada_2) or not entrada_3
# Out:
# True

# %%
entrada_1 = (2*5) > 3
entrada_2 = 13<12
entrada_3 = False

print(not ((entrada_1 and entrada_2)or(entrada_1 and entrada_3)))
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)
